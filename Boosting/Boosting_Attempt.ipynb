# %%
# !git clone https://github.com/HazyResearch/KGEmb
# Please upload the KGEmb folder here and proceed

# %cd KGEmb/
# Out:
# Cloning into 'KGEmb'...
# remote: Enumerating objects: 150, done.
# remote: Counting objects: 100% (150/150), done.
# remote: Compressing objects: 100% (105/105), done.
# remote: Total 150 (delta 91), reused 91 (delta 42), pack-reused 0
# Receiving objects: 100% (150/150), 33.77 KiB | 11.26 MiB/s, done.
# Resolving deltas: 100% (91/91), done.
# /content/KGEmb

# %%
# !pip install virtualenv
# !virtualenv -p python3.7 hyp_kg_env
# Out:
# ...
#      |████████████████████████████████| 7.2MB 27.9MB/s
# ...
#      |████████████████████████████████| 337kB 52.0MB/s
# ...
# created virtual environment CPython3.7.10.final.0-64 in 796ms
#   creator CPython3Posix(dest=/content/KGEmb/hyp_kg_env, clear=False, no_vcs_ignore=False, global=False)
#   seeder FromAppData(download=False, pip=bundle, setuptools=bundle, wheel=bundle, via=copy, app_data_dir=/root/.local/share/virtualenv)
#     added seed packages: pip==21.1.1, setuptools==56.0.0, wheel==0.36.2
#   activators BashActivator,CShellActivator,FishActivator,PowerShellActivator,PythonActivator,XonshActivator

# %%
# %%shell
# source hyp_kg_env/bin/activate
# pip install -r requirements.txt
#
# source set_env.sh
# source datasets/download.sh
# python datasets/process.py
#
# python run.py --dataset WN18RR --model TransE --max_epochs 100 --patience 10 --rank 32 --neg_sample_size 50 --learning_rate 0.1 --batch_size 1000
# Out:
# ...
#      |████████████████████████████████| 15.3 MB 170 kB/s
# ...
#      |████████████████████████████████| 804.1 MB 2.6 kB/s
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))': /simple/tqdm/
# ...
#      |████████████████████████████████| 75 kB 5.2 MB/s
# ...
# --2021-05-10 05:08:05--  https://dl.fbaipublicfiles.com/kbc/data.tar.gz
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 172.67.9.4, 104.22.74.142, 104.22.75.142, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|172.67.9.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13696853 (13M) [application/gzip]
# Saving to: ‘data.tar.gz’
#
# data.tar.gz         100%[===================>]  13.06M  11.9MB/s    in 1.1s
#
# 2021-05-10 05:08:07 (11.9 MB/s) - ‘data.tar.gz’ saved [13696853/13696853]
#
# data/
# data/FB15K/
# ...

# %%
# %%shell
# source hyp_kg_env/bin/activate
# #pip install -r requirements.txt
#
# source set_env.sh
# #source datasets/download.sh
# #python datasets/process.py
#
# python boost10.py --dataset WN18RR --model TransE --max_epochs 10 --patience 3 --rank 32 --neg_sample_size 50 --learning_rate 0.1 --batch_size 1000
# Out:
# 2021-05-10 13:53:25,020 INFO     Saving logs in: /content/KGEmb/logs/05_10/WN18RR/TransE_13_53_25
# 2021-05-10 13:53:25,338 INFO     	 (40943, 22, 40943)
# 2021-05-10 13:53:25,425 INFO     Total number of parameters 1392766
# 2021-05-10 13:53:28,542 INFO     	 Start training
# train loss: 100% 173670/173670 [00:01<00:00, 95729.63ex/s, loss=0.0716]
# 2021-05-10 13:53:30,374 INFO     	 Epoch 0 | average train loss: 0.0934
# 2021-05-10 13:53:30,386 INFO     	 Epoch 0 | average valid loss: 0.0890
# train loss: 100% 173670/173670 [00:01<00:00, 99373.02ex/s, loss=0.0521]
# 2021-05-10 13:53:32,154 INFO     	 Epoch 1 | average train loss: 0.0551
# 2021-05-10 13:53:32,170 INFO     	 Epoch 1 | average valid loss: 0.0863
# train loss: 100% 173670/173670 [00:01<00:00, 98138.65ex/s, loss=0.0443]
# 2021-05-10 13:53:33,961 INFO     	 Epoch 2 | average train loss: 0.0456
# 2021-05-10 13:53:33,973 INFO     	 Epoch 2 | average valid loss: 0.0835
# ...

# %%
# %%shell
# #source hyp_kg_env/bin/activate
# #pip install -r requirements.txt
#
# source set_env.sh
# #source datasets/download.sh
# #python datasets/process.py
#
# python test.py --model_dir '/content/KGEmb/logs/05_10/WN18RR/TransE_05_08_43'
#
# #import pdb; pdb.set_trace()
# Out:
# 	 test MR: 3379.30 | MRR: 0.175 | H@1: 0.031 | H@3: 0.263 | H@10: 0.445
